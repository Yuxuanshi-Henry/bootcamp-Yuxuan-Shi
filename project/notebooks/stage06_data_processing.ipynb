# %% [markdown]
# # Stage 06: Data Processing

# %% [markdown]
# ## 1. Load Raw Data Set

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('../src')
from utils import fill_missing_median, drop_missing, normalize_data

# %%
data_features = pd.read_csv('../data/raw/features.csv')
data_targets = pd.read_csv('../data/raw/targets.csv')

# %%
data_features
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0          A11           6        A34        A43        1169        A65
# 1          A12          48        A32        A43        5951        A61
# 2          A14          12        A34        A46        2096        A61
# 3          A11          42        A32        A42        7882        A61
# 4          A11          24        A33        A40        4870        A61
# ..         ...         ...        ...        ...         ...        ...
# 995        A14          12        A32        A42        1736        A61
# 996        A11          30        A32        A41        3857        A61
# 997        A14          12        A32        A43         804        A61
# 998        A11          45        A32        A43        1845        A61
# 999        A12          45        A34        A41        4576        A62
#
#     Attribute7  Attribute8 Attribute9 Attribute10  Attribute11 Attribute12  \
# ...

# %%
data_targets
# Out:
#      class
# 0        1
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      2
# 999      1
#
# [1000 rows x 1 columns]

# %%
# due to the definition of targets, we make adjustments here. (bad: 2->0,good:1->1)
data_targets['class'] = (data_targets['class'] != 2).astype(int) * data_targets['class']
data_targets
# Out:
#      class
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      0
# 999      1
#
# [1000 rows x 1 columns]

# %% [markdown]
# # 2. Apply Cleaning Function

# %%
# Fill na to median
data_features = fill_missing_median(data_features)
data_targets = fill_missing_median(data_targets)

# %%
# normalize
# data_features = normalize_data(data_features)
# data_features.head()

# %%
data_features.to_csv('../data/processed/features_simple_processed.csv', index=False)
data_targets.to_csv('../data/processed/targets_simple_processed.csv', index=False)

# %%
import pandas as pd
data = pd.read_csv('../data/processed/features_simple_processed.csv')
variables = pd.read_csv('../data/raw/variable_name.csv')
mapping = dict(zip(variables['Attribute'], variables['Description']))
data.rename(columns=mapping, inplace=True)
data.to_csv('../data/processed/features_simple_processed.csv', index=False)
